# %% [markdown]
# # Budgeted Temporal Fuzzy Recycling (BT-FR) V3
#
# Three replacement rates matched to the observed ReGraMa, ReDo and SNR dose range, using seeds 15–17. The temporal fuzzy score ranks units while an independent continual budget controls dose. All nine targeted runs finish before the nine exact-yoked random controls. Existing baselines are reused.

# %%
import os, sys
from pathlib import Path

REPO = Path(os.environ["NEURON_DEATH_SOURCE"])
sys.path.insert(0, str(REPO))
from scripts.run_fuzzy_v3_sweep import run_sweep

run_sweep(REPO, Path(os.environ["NEURON_DEATH_DATA"]))
