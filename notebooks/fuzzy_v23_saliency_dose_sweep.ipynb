# %% [markdown]
# # Temporal fuzzy V2.3 process/saliency dose sweep
#
# Four settings, seeds 15–17. All twelve targeted runs finish before the twelve exact-yoked controls. Existing baselines are reused.
#
# This frozen sweep raises process-health coverage while separately controlling the equivalent saliency guard, spanning approximately 9k–17k projected resets without changing the V2 reset operation.

# %%
import os, sys
from pathlib import Path

REPO = Path(os.environ["NEURON_DEATH_SOURCE"])
sys.path.insert(0, str(REPO))
from scripts.run_fuzzy_v23_sweep import run_sweep

run_sweep(REPO, Path(os.environ["NEURON_DEATH_DATA"]))
