# %% [markdown]
# # Recovery-Accelerated SNR (RA-SNR) V4
#
# Four post-reset recovery settings on seeds 15–17. The SNR eta=0.08 detector and reset rule are unchanged; only the newly reset unit's outgoing gradient is temporarily amplified. Existing SNR, ReDo, ReGraMa and baseline runs are reused.

# %%
import os, sys
from pathlib import Path

REPO = Path(os.environ["NEURON_DEATH_SOURCE"])
sys.path.insert(0, str(REPO))
from scripts.run_fuzzy_v4_sweep import run_sweep

run_sweep(REPO, Path(os.environ["NEURON_DEATH_DATA"]))
