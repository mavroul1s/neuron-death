# %% [markdown]
# # Temporal fuzzy V2.1 dose sweep
#
# Thresholds 0.30 and 0.50; development seeds 15–17. Six targeted runs finish before six exact-yoked random controls. Existing deterministic baselines are reused in analysis.
#
# Two T4s run independent experiments. The session has one 10-hour budget, including 30 minutes reserved for preserving results. The separate V2.1 plan is frozen before execution; method logic remains in `src/`.

# %%
import os, sys
from pathlib import Path

REPO = Path(os.environ["NEURON_DEATH_SOURCE"])
sys.path.insert(0, str(REPO))
from scripts.run_fuzzy_v21_sweep import run_sweep

run_sweep(source=REPO, data=Path(os.environ["NEURON_DEATH_DATA"]))
